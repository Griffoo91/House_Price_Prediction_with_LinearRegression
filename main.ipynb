# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Load and explore data

# %%
#load the dataset
data = pd.read_csv("rent_apts.csv")

#explore the data
data

# %%
data.describe()
# Out:
#             sq_mtrs     Bedrooms    Bathrooms
# count   1846.000000  1845.000000  1557.000000
# mean     327.226977     2.577778     2.595376
# std     2048.784581     0.819399     1.000349
# min        0.000000     0.000000     1.000000
# 25%        2.000000     2.000000     2.000000
# 50%        3.000000     3.000000     2.000000
# 75%        4.000000     3.000000     3.000000
# max    40470.000000     6.000000     6.000000

# %% [markdown]
# # data cleaning and wrangling
#  drop agency, neighborhood,sq meters, link columns and all rows with zero/NaN values
#  convert price to ints
#  convert Neighborhood to ints

# %%
# Drop "Neighborhood", "sq_meters", "link" columns and all rows with nan values
del data["Agency"]
del data["Neighborhood"]
del data["sq_mtrs"]
del data["link"]
data = data.dropna()
data
# Out:
#             Price  Bedrooms  Bathrooms
# 0     KSh 155,000       4.0        4.0
# 1     KSh 100,000       3.0        4.0
# 2      KSh 75,000       3.0        5.0
# 3     KSh 135,000       3.0        4.0
# 6     KSh 100,000       2.0        3.0
# ...           ...       ...        ...
# 1841  KSh 180,000       3.0        3.0
# 1842  KSh 180,000       3.0        4.0
# 1844  KSh 180,000       2.0        2.0
# 1845  KSh 180,000       4.0        5.0
# 1846  KSh 180,000       4.0        4.0
#
# [1557 rows x 3 columns]

# %%
# convert Price to ints
data["Price"] = data["Price"].str.replace("KSh ", "")
data
data["Price"] = data["Price"].str.replace(",", "")
data
data["Price"] = pd.to_numeric(data["Price"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1557 entries, 0 to 1846
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1557 non-null   int64
#  1   Bedrooms   1557 non-null   float64
#  2   Bathrooms  1557 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 48.7 KB
# /tmp/ipykernel_6740/944412924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Price"] = data["Price"].str.replace("KSh ", "")
# /tmp/ipykernel_6740/944412924.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data.corr()
# Out:
#               Price  Bedrooms  Bathrooms
# Price      1.000000  0.352336   0.440472
# Bedrooms   0.352336  1.000000   0.731506
# Bathrooms  0.440472  0.731506   1.000000

# %% [markdown]
# # Visualize the data

# %% [markdown]
# # Prepare data

# %%
# Extract features X and the target variable y
X = data[["Bedrooms", "Bathrooms"]]
y = data["Price"]

# split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.40, random_state=32)

# %% [markdown]
# # train the model

# %%
# create a linear Regression model
clf = DecisionTreeRegressor()

# train the model on the training set
clf.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# # predictions

# %%
# making prediction on the testing data

clf.predict(X_test[:5])
# Out:
# array([110204.08163265,  85228.63247863,  78775.        , 110204.08163265,
#         85228.63247863])

# %%
str(y_test[:5])
# Out:
# '478      70000\n469      67000\n1156    110000\n1055    100000\n332      55000\nName: Price, dtype: int64'

# %% [markdown]
# # ealuating the model

# %%
# calculating the mean squared error
clf.score(X_test, y_test)
# Out:
# 0.22702945370073635
